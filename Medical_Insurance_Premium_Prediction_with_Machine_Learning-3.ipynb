# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-darkgrid")

# setting the style of the notebook to be monokai theme
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
# read the csv file
insurance_df = pd.read_csv('/content/drive/MyDrive/insurance.csv')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# # TASK #3: PERFORM EXPLORATORY DATA ANALYSIS - PART 1

# %%
insurance_df.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# check if there are any Null values
sns.heatmap(insurance_df.isnull(), yticklabels = False, cbar = False, cmap="Blues")
# Out:
# <Axes: >

# %%
# check if there are any Null values
insurance_df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Check the dataframe info
insurance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Grouping by region to see any relationship between region and charges
# Seems like south east region has the highest charges and body mass index
df_region = insurance_df.groupby(by = 'region').mean(numeric_only=True)
df_region
# Out:
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# **PRACTICE OPPORTUNITY #1 [OPTIONAL]:**
# - **Group data by 'age' and examine the relationship between 'age' and 'charges'**

# %%
df_age = insurance_df.groupby(by = 'age').mean(numeric_only=True)
df_age
# Out:
#            bmi  children       charges
# age
# 18   31.326159  0.449275   7086.217556
# 19   28.596912  0.426471   9747.909335
# 20   30.632759  0.862069  10159.697736
# 21   28.185714  0.785714   4730.464330
# 22   31.087679  0.714286  10012.932802
# 23   31.454464  1.000000  12419.820040
# 24   29.142679  0.464286  10648.015962
# 25   29.693929  1.285714   9838.365311
# 26   29.428929  1.071429   6133.825309
# 27   29.333571  0.964286  12184.701721
# 28   29.482143  1.285714   9069.187564
# 29   29.383148  1.259259  10430.158727
# 30   30.557593  1.555556  12719.110358
# 31   29.918333  1.407407  10196.980573
# 32   31.597692  1.269231   9220.300291
# 33   31.163077  1.538462  12351.532987
# 34   30.274038  1.153846  11613.528121
# 35   31.394800  1.680000  11307.182031
# 36   29.374200  1.240000  12204.476138
# 37   31.216600  1.520000  18019.911877
# 38   28.996600  1.480000   8102.733674
# 39   29.910200  2.200000  11778.242945
# 40   30.139074  1.592593  11772.251310
# 41   31.506852  1.407407   9653.745650
# 42   30.328148  1.000000  13061.038669
# 43   30.204444  1.629630  19267.278653
# 44   30.844259  1.222222  15859.396587
# 45   29.778966  1.482759  14830.199856
# 46   31.340862  1.620690  14342.590639
# 47   30.664310  1.379310  17653.999593
# 48   31.925690  1.310345  14632.500445
# 49   30.313929  1.500000  12696.006264
# 50   31.132241  1.310345  15663.003301
# 51   31.727069  1.103448  15682.255867
# 52   32.936034  1.482759  18256.269719
# 53   30.360893  1.250000  16020.930755
# 54   31.234286  1.428571  18758.546475
# 55   31.950000  0.961538  16164.545488
# 56   31.600962  0.769231  15025.515837
# 57   30.844423  0.615385  16447.185250
# 58   32.718200  0.240000  13878.928112
# 59   30.572000  1.200000  18895.869532
# 60   30.332826  0.347826  21979.418507
# 61   32.548261  0.739130  22024.457609
# 62   32.342609  0.565217  19163.856573
# 63   31.923478  0.565217  19884.998461
# 64   32.976136  0.772727  23275.530837

# %% [markdown]
# # TASK #4: PERFORM FEATURE ENGINEERING

# %%
# Check unique values in the 'sex' column
insurance_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# convert categorical variable to numerical
insurance_df['sex'] = insurance_df['sex'].apply(lambda x:0   if x == 'female' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children smoker     region      charges
# 0   19    0  27.900         0    yes  southwest  16884.92400
# 1   18    1  33.770         1     no  southeast   1725.55230
# 2   28    1  33.000         3     no  southeast   4449.46200
# 3   33    1  22.705         0     no  northwest  21984.47061
# 4   32    1  28.880         0     no  northwest   3866.85520

# %%
# Check the unique values in the 'smoker' column
insurance_df['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
# Convert categorical variable to numerical
insurance_df['smoker'] = insurance_df['smoker'].apply(lambda x: 0 if x == 'no' else 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges
# 0   19    0  27.900         0       1  southwest  16884.92400
# 1   18    1  33.770         1       0  southeast   1725.55230
# 2   28    1  33.000         3       0  southeast   4449.46200
# 3   33    1  22.705         0       0  northwest  21984.47061
# 4   32    1  28.880         0       0  northwest   3866.85520

# %%
# Check unique values in 'region' column
insurance_df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_dummies = pd.get_dummies(insurance_df['region'], drop_first = True)

# %%
region_dummies
# Out:
#       northwest  southeast  southwest
# 0         False      False       True
# 1         False       True      False
# 2         False       True      False
# 3          True      False      False
# 4          True      False      False
# ...         ...        ...        ...
# 1333       True      False      False
# 1334      False      False      False
# 1335      False       True      False
# 1336      False      False       True
# 1337       True      False      False
#
# [1338 rows x 3 columns]

# %%
insurance_df = pd.concat([insurance_df, region_dummies], axis = 1)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker     region      charges  northwest  \
# 0   19    0  27.900         0       1  southwest  16884.92400      False
# 1   18    1  33.770         1       0  southeast   1725.55230      False
# 2   28    1  33.000         3       0  southeast   4449.46200      False
# 3   33    1  22.705         0       0  northwest  21984.47061       True
# 4   32    1  28.880         0       0  northwest   3866.85520       True
#
#    southeast  southwest
# 0      False       True
# 1       True      False
# 2       True      False
# 3      False      False
# 4      False      False

# %%
# Let's drop the original 'region' column
insurance_df.drop(['region'], axis = 1, inplace = True)

# %%
insurance_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  northwest  southeast  \
# 0   19    0  27.900         0       1  16884.92400      False      False
# 1   18    1  33.770         1       0   1725.55230      False       True
# 2   28    1  33.000         3       0   4449.46200      False       True
# 3   33    1  22.705         0       0  21984.47061       True      False
# 4   32    1  28.880         0       0   3866.85520       True      False
#
#    southwest
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False

# %% [markdown]
# # TASK #5: PERFORM DATA VISUALIZATION

# %%
insurance_df[['age','sex','bmi','children','smoker','charges']].hist(bins = 30, figsize=(12,12))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>],
#        [<Axes: title={'center': 'bmi'}>,
#         <Axes: title={'center': 'children'}>],
#        [<Axes: title={'center': 'smoker'}>,
#         <Axes: title={'center': 'charges'}>]], dtype=object)

# %%
# plot pairplot
sns.pairplot(insurance_df)

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'age', y = 'charges', data = insurance_df)
plt.show()

# %%
plt.figure(figsize = (15, 6))
sns.regplot(x = 'bmi', y = 'charges', data = insurance_df)
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #2 [OPTIONAL]:**
#  - **Calculate and plot the correlation matrix**
#  - **Which feature has the most positive correlation with charges?**

# %%
insurance_df.corr()
# Out:
#                 age       sex       bmi  children    smoker   charges  \
# age        1.000000 -0.020856  0.109272  0.042469 -0.025019  0.299008
# sex       -0.020856  1.000000  0.046371  0.017163  0.076185  0.057292
# bmi        0.109272  0.046371  1.000000  0.012759  0.003750  0.198341
# children   0.042469  0.017163  0.012759  1.000000  0.007673  0.067998
# smoker    -0.025019  0.076185  0.003750  0.007673  1.000000  0.787251
# charges    0.299008  0.057292  0.198341  0.067998  0.787251  1.000000
# northwest -0.000407 -0.011156 -0.135996  0.024806 -0.036945 -0.039905
# southeast -0.011642  0.017117  0.270025 -0.023066  0.068498  0.073982
# southwest  0.010016 -0.004184 -0.006205  0.021914 -0.036945 -0.043210
#
#            northwest  southeast  southwest
# age        -0.000407  -0.011642   0.010016
# sex        -0.011156   0.017117  -0.004184
# bmi        -0.135996   0.270025  -0.006205
# children    0.024806  -0.023066   0.021914
# smoker     -0.036945   0.068498  -0.036945
# charges    -0.039905   0.073982  -0.043210
# northwest   1.000000  -0.346265  -0.320829
# southeast  -0.346265   1.000000  -0.346265
# southwest  -0.320829  -0.346265   1.000000

# %%
plt.figure(figsize = (10,10))
sns.heatmap(insurance_df.corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # TASK #6: CREATE TRAINING AND TESTING DATASET

# %%
insurance_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges', 'northwest',
#        'southeast', 'southwest'],
#       dtype='object')

# %%
X = insurance_df.drop(columns=['charges'])
y = insurance_df['charges']

# %%
X
# Out:
#       age  sex     bmi  children  smoker  northwest  southeast  southwest
# 0      19    0  27.900         0       1      False      False       True
# 1      18    1  33.770         1       0      False       True      False
# 2      28    1  33.000         3       0      False       True      False
# 3      33    1  22.705         0       0       True      False      False
# 4      32    1  28.880         0       0       True      False      False
# ...   ...  ...     ...       ...     ...        ...        ...        ...
# 1333   50    1  30.970         3       0       True      False      False
# 1334   18    0  31.920         0       0      False      False      False
# 1335   18    0  36.850         0       0      False       True      False
# 1336   21    0  25.800         0       0      False      False       True
# 1337   61    0  29.070         0       1       True      False      False
#
# [1338 rows x 8 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
X.shape
# Out:
# (1338, 8)

# %%
y.shape
# Out:
# (1338,)

# %%
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
y = y.reshape(-1,1)

# %%
# Only take the numerical variables and scale them
X
# Out:
# array([[19.  ,  0.  , 27.9 , ...,  0.  ,  0.  ,  1.  ],
#        [18.  ,  1.  , 33.77, ...,  0.  ,  1.  ,  0.  ],
#        [28.  ,  1.  , 33.  , ...,  0.  ,  1.  ,  0.  ],
#        ...,
#        [18.  ,  0.  , 36.85, ...,  0.  ,  1.  ,  0.  ],
#        [21.  ,  0.  , 25.8 , ...,  0.  ,  0.  ,  1.  ],
#        [61.  ,  0.  , 29.07, ...,  1.  ,  0.  ,  0.  ]], dtype=float32)

# %%
y.shape
# Out:
# (1338, 1)

# %%
#scaling the data before feeding the model
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_x = StandardScaler()
X = scaler_x.fit_transform(X)

scaler_y = MinMaxScaler()
y = scaler_y.fit_transform(y.reshape(-1,1))

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Split the data into 20% Testing and 80% Training**
# - **Double check that the split was successful by getting the shape of both the training and testing datasets**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= 0.2, random_state= 10)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1070, 8)
# (268, 8)

# %% [markdown]
# # TASK #7: TRAIN AND EVALUATE A LINEAR REGRESSION MODEL IN SCIKIT-LEARN

# %%
# using linear regression model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, accuracy_score

regression_model_sklearn = LinearRegression()
regression_model_sklearn.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression_model_sklearn_accuracy = regression_model_sklearn.score(X_test, y_test)
regression_model_sklearn_accuracy
# Out:
# 0.6953286528587341

# %%
y_predict = regression_model_sklearn.predict(X_test)

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 268

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt


RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.104
# MSE = 0.01088715810328722
# MAE = 0.07270876318216324
# R2 = 0.6953286528587341
# Adjusted R2 = 0.6859179548775367

# %% [markdown]
# # TASK #8: TRAIN AND EVALUATE AN ARTIFICIAL NEURAL NETWORK-BASED REGRESSION MODEL

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 50)             │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 150)            │         7,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 150)            │        22,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 50)             │         7,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,351 (149.81 KB)
#  Trainable params: 38,351 (149.81 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
ANN_model.compile(optimizer='Adam', loss='mean_squared_error')
epochs_hist = ANN_model.fit(X_train, y_train, epochs=100, batch_size=20, validation_split=0.2)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1315 - val_loss: 0.0197
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0342 - val_loss: 0.0131
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0209 - val_loss: 0.0138
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0148 - val_loss: 0.0081
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0145 - val_loss: 0.0090
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0145 - val_loss: 0.0083
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0118 - val_loss: 0.0116
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0105 - val_loss: 0.0092
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0113 - val_loss: 0.0074
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0114 - val_loss: 0.0131
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0099 - val_loss: 0.0082
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0100 - val_loss: 0.0132
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0086 - val_loss: 0.0082
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0100 - val_loss: 0.0081
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0113 - val_loss: 0.0105
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0104 - val_loss: 0.0094
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0098 - val_loss: 0.0090
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0099 - val_loss: 0.0104
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - val_loss: 0.0108
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0089 - val_loss: 0.0112
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0099 - val_loss: 0.0107
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0105
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0090
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0076 - val_loss: 0.0099
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0080 - val_loss: 0.0069
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0081 - val_loss: 0.0097
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0083 - val_loss: 0.0103
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0116
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0082 - val_loss: 0.0127
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - val_loss: 0.0136
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0077 - val_loss: 0.0096
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0078 - val_loss: 0.0093
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 0.0079
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0120
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0103
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0109
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - val_loss: 0.0101
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0078 - val_loss: 0.0114
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0104
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0067 - val_loss: 0.0096
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0077
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - val_loss: 0.0073
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0063 - val_loss: 0.0095
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0064 - val_loss: 0.0100
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0066 - val_loss: 0.0112
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0067 - val_loss: 0.0084
# Epoch 58/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074 - val_loss: 0.0076
# Epoch 59/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0068 - val_loss: 0.0080
# Epoch 60/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0101
# Epoch 61/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0051 - val_loss: 0.0115
# Epoch 62/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0066 - val_loss: 0.0085
# Epoch 63/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0073 - val_loss: 0.0077
# Epoch 64/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0075 - val_loss: 0.0082
# Epoch 65/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - val_loss: 0.0105
# Epoch 66/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0098
# Epoch 67/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 68/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - val_loss: 0.0093
# Epoch 69/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0080
# Epoch 70/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - val_loss: 0.0118
# Epoch 71/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - val_loss: 0.0093
# Epoch 72/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 73/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 74/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0094
# Epoch 75/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 76/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - val_loss: 0.0082
# Epoch 77/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0059 - val_loss: 0.0083
# Epoch 78/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0069 - val_loss: 0.0098
# Epoch 79/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0063 - val_loss: 0.0079
# Epoch 80/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 81/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059 - val_loss: 0.0095
# Epoch 82/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - val_loss: 0.0090
# Epoch 83/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0054 - val_loss: 0.0084
# Epoch 84/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0085
# Epoch 85/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064 - val_loss: 0.0078
# Epoch 86/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0096
# Epoch 87/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 88/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0060 - val_loss: 0.0083
# Epoch 89/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 90/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0091
# Epoch 91/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0097
# Epoch 92/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0057 - val_loss: 0.0082
# Epoch 93/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 94/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0084
# Epoch 95/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0085
# Epoch 96/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0087
# Epoch 97/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 98/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059 - val_loss: 0.0094
# Epoch 99/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0063 - val_loss: 0.0080
# Epoch 100/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0060 - val_loss: 0.0073

# %%
result = ANN_model.evaluate(X_test, y_test)
accuracy_ANN = 1 - result
print("Accuracy : {}".format(accuracy_ANN))
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0088
# Accuracy : 0.991386853158474

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = ANN_model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler_y.inverse_transform(y_predict)
y_test_orig = scaler_y.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# Text(0, 0.5, 'True Values')

# %%
k = X_test.shape[1]
n = len(X_test)
n

from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 0.093
# MSE = 0.008613144978880882
# MAE = 0.052349753677845
# R2 = 0.7589657306671143
# Adjusted R2 = 0.7515206567108861

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Dropout is a regularization technique that is used to improve the network generalization ability. Experiment adding dropout layers to enahnce network generalization ability**
# - **Retrain the network and assess its performance**

# %%
ANN_model = keras.Sequential()
ANN_model.add(Dense(50, input_dim = 8))
ANN_model.add(Activation('relu'))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(150))
ANN_model.add(Activation('relu'))
ANN_model.add(Dropout(0.5))
ANN_model.add(Dense(50))
ANN_model.add(Activation('linear'))
ANN_model.add(Dense(1))
ANN_model.compile(loss = 'mse', optimizer = 'adam')
ANN_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_25 (Dense)                │ (None, 50)             │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 150)            │         7,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 150)            │        22,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 50)             │         7,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,351 (149.81 KB)
#  Trainable params: 38,351 (149.81 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import joblib

# Save scalers
joblib.dump(scaler_x, "scaler_x.pkl")
joblib.dump(scaler_y, "scaler_y.pkl")

from google.colab import files

files.download("scaler_y.pkl")

# %%
files.download("scaler_x.pkl")

# %%
ANN_model.save_weights("insurance_weights.weights.h5")

# %%
from google.colab import files
files.download("insurance_weights.weights.h5")

# %% [markdown]
# # App.py

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import tensorflow as tf

# Load your trained ANN model
model = tf.keras.models.load_model("insurance_model.h5")

# 🎨 Page configuration
st.set_page_config(
    page_title="Medical Insurance Premium Predictor",
    page_icon="💰",
    layout="centered",
    initial_sidebar_state="expanded"
)

# 🌟 Custom CSS for premium look
st.markdown("""
    <style>
        .main {
            background-color: #f9f9f9;
        }
        .stApp {
            background-color: #f5f7fa;
        }
        h1 {
            color: #2C3E50;
            text-align: center;
            font-family: 'Helvetica Neue', sans-serif;
        }
        .stButton>button {
            color: white;
            background: linear-gradient(90deg, #4b6cb7 0%, #182848 100%);
            border-radius: 10px;
            height: 3em;
            width: 100%;
            font-size: 16px;
        }
        .stSuccess {
            font-size: 20px;
            color: #27ae60;
            text-align: center;
        }
    </style>
""", unsafe_allow_html=True)

# 🏥 App Title
st.title("🏥 Medical Insurance Premium Prediction")
st.markdown("#### Predict your expected **insurance premium** based on lifestyle and health factors.")

# 📊 Sidebar for inputs
st.sidebar.header("📌 Input Your Details")

age = st.sidebar.number_input("Age", min_value=18, max_value=100, value=30)
sex = st.sidebar.selectbox("Sex", ["male", "female"])
bmi = st.sidebar.number_input("BMI", min_value=10.0, max_value=60.0, value=25.0, step=0.1)
children = st.sidebar.number_input("Number of Children", min_value=0, max_value=10, value=0)
smoker = st.sidebar.selectbox("Smoker", ["yes", "no"])
region = st.sidebar.selectbox("Region", ["northeast", "northwest", "southeast", "southwest"])

# 🔄 Encode categorical variables
sex = 1 if sex == "male" else 0
smoker = 1 if smoker == "yes" else 0
region_dict = {"northeast": 0, "northwest": 1, "southeast": 2, "southwest": 3}
region = region_dict[region]

# 🧮 Feature array
features = np.array([[age, sex, bmi, children, smoker, region]])

# 🎯 Prediction
if st.sidebar.button("💡 Predict Premium"):
    prediction = model.predict(features)
    st.success(f"💰 Estimated Annual Premium: **${prediction[0][0]:,.2f}**")

    # Extra info
    st.markdown("""
    ---
    ✅ **Note:** Predictions are based on the dataset used for training.
    Lifestyle factors like **smoking** and **BMI** significantly increase premium costs.
    """)

# 📌 Footer
st.markdown("---")
st.markdown("Made with ❤️ using **Streamlit & TensorFlow** | Demo Project")
# Out:
# Writing app.py

# %%
from google.colab import files
files.download("app.py")

# %%
# %%writefile requirements.txt
# streamlit
# numpy
# pandas
# tensorflow
# scikit-learn
# Out:
# Writing requirements.txt

# %%
from google.colab import files
files.download("requirements.txt")

# %%
# !echo "3.10" > .python-version

# %%
ANN_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 50)             │           450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 150)            │         7,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 150)            │        22,650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 150)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 50)             │         7,550 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,351 (149.81 KB)
#  Trainable params: 38,351 (149.81 KB)
#  Non-trainable params: 0 (0.00 B)
